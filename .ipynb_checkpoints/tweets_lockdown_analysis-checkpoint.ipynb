# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import torch
import string
import nltk
import pandas as pd
import tweepy
import json
import csv
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Obtaining tweets

# %%
class Covid19Listener(tweepy.StreamListener):

    def __init__(self, f):
        super().__init__()
        self.i = 0
        self.file = open(f, 'w', newline='')
        self.writer = csv.writer(self.file, delimiter=',')

    def on_status(self, status):
        lan = status._json['lang']
        if hasattr(status, 'retweeted_status'):
            try:
                tweet = status.retweeted_status.extended_tweet["full_text"]
            except:
                tweet = status.retweeted_status.text
        else:
            try:
                tweet = status.extended_tweet["full_text"]
            except AttributeError:
                tweet = status.text
        
        if lan == 'en':
            self.writer.writerow([self.i, tweet])
            self.i += 1
            print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
            print('tweet # {}'.format(self.i))
            print('-----------')
            print(tweet)


        def on_error(self, status):
            print(status)

# %%
with open('apis.json') as js:
    keys = json.load(js)

access_token = keys['access token']
access_token_secret = keys['access secret']
consumer_key = keys['consumer key']
consumer_secret = keys['consumer secret']

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
#spy = Covid19Listener('data/raw_tweets1.csv')
#stream = tweepy.Stream(auth, spy, tweet_mode='extended')
#stream.filter(track=['corona', 'covid19', 'coronavirus', 'corona virus', 'lockdown'])

# %% [markdown]
# ## Preprocessing tweets

# %%
Documents = {}
with open('data/raw_tweets1.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        key, txt = row[0], row[1]
        Documents[key] = txt

# %%
#import pickle 
#with open('data/tweets.pkl', 'wb') as f:
#    pickle.dump(Documents, f)

# %%
import pickle
documents = {}
with open('data/tweets.pkl', 'rb') as f:
    documents = pickle.load(f)

# %%
del documents['1']  # empty
del documents['2']  # empty

# %%
doc = []
for k in documents:
  doc.append(documents[k])

# %%
# nltk.download()

# %%
table = str.maketrans('', '', string.punctuation)
stop_words = set(stopwords.words('english'))


clean_tweets = []
for tweet in doc:
  tokens = word_tokenize(tweet)
  tokens = [w.translate(table) for w in tokens]
  tokens = [word for word in tokens if word.isalpha()]
  tweet = [w for w in tokens if w not in stop_words]
  if len(tweet) > 2:
    clean_tweets.append(' '.join(tweet))

# %%
with open('clean_tweets.pkl', 'wb') as f:
    pickle.dump(clean_tweets, f)

# %%
clean_tweets = []
with open('data/clean_tweets.pkl', 'rb') as f:
    clean_tweets =  pickle.load(f)

# %% [markdown]
# ### Quick sentiment analysis

# %%
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# #### Wordcloud

# %%
stop = STOPWORDS.copy()
stop.add('https')
wordcloud_spam = WordCloud(background_color="white", stopwords=stop).generate(' '.join(doc))
plt.figure(figsize = (15,15))
plt.imshow(wordcloud_spam, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# we couldve removed https from the words but wtv ..

# %%
pd.set_option('display.max_colwidth', -1)
sentiment = pd.DataFrame()
sentiment['tweet'] = clean_tweets
sentiment['Polarity'] = sentiment['tweet'].apply(lambda t: TextBlob(t).sentiment[0])

# %%
def get_label(t):
  if t < -0.05:
    return 'neg'
  elif t >= 0.15:
    return 'pos'
  else:
    return 'neutral'

sentiment['sentiment'] = sentiment['Polarity'].apply(get_label)

# %%
px.histogram(sentiment['sentiment'], x='sentiment', nbins=3, title='Twitter Sentiment analysis')
# Out:
# <div>
#
#
#             <div id="338e0a03-5ece-4f32-9195-ca132fa8ee72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("338e0a03-5ece-4f32-9195-ca132fa8ee72")) {
#                     Plotly.newPlot(
#                         '338e0a03-5ece-4f32-9195-ca132fa8ee72',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "sentiment=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 3, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["neutral", "neutral", "neutral", "neg", "neutral", "neutral", "neg", "pos", "pos", "pos", "neutral", "neutral", "neg", "pos", "neutral", "neg", "pos", "neutral", "neutral", "pos", "pos", "neutral", "pos", "neg", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neg", "neutral", "neg", "neutral", "neg", "pos", "neg", "neutral", "neutral", "neutral", "neg", "neg", "neutral", "pos", "neutral", "pos", "neutral", "pos", "neutral", "neutral", "neg", "pos", "neg", "pos", "neg", "neg", "neutral", "pos", "neutral", "neg", "pos", "neg", "neg", "pos", "neutral", "neutral", "neg", "pos", "neutral", "pos", "neutral", "neutral", "pos", "neutral", "neutral", "neutral", "neutral", "pos", "neutral", "pos", "pos", "neutral", "neg", "neg", "neutral", "pos", "neutral", "neg", "neutral", "neg", "neg", "neutral", "pos", "pos", "pos", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "pos", "pos", "neutral", "neutral", "neg", "pos", "neutral", "neg", "neg", "pos", "neutral", "neg", "neutral", "pos", "pos", "neg", "neg", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "neg", "neutral", "pos", "neg", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "neutral", "neutral", "pos", "pos", "pos", "pos", "neutral", "neutral", "pos", "neutral", "neutral", "pos", "neutral", "neg", "neutral", "neutral", "neg", "pos", "pos", "neg", "pos", "neg", "pos", "neg", "neg", "neutral", "neutral", "pos", "pos", "neutral", "neutral", "neutral", "pos", "neg", "neutral", "neutral", "pos", "pos", "neutral", "neutral", "neg", "neg", "neutral", "pos", "neutral", "pos", "neg", "neutral", "pos", "neutral", "neutral", "pos", "neg", "pos", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "neg", "neutral", "pos", "neg", "pos", "neutral", "neutral", "pos", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neutral", "neg", "neg", "pos", "pos", "neg", "neg", "neutral", "pos", "neutral", "neutral", "pos", "neutral", "neg", "neutral", "neutral", "neg", "pos", "pos", "neutral", "pos", "pos", "pos", "pos", "neutral", "pos", "pos", "neutral", "neutral", "neutral", "pos", "neg", "neg", "neutral", "neg", "neutral", "neg", "neg", "pos", "pos", "pos", "neutral", "neutral", "pos", "pos", "neutral", "pos", "neutral", "neg", "neg", "neg", "neg", "neutral", "neutral", "pos", "neg", "pos", "pos", "neg", "pos", "neg", "neutral", "neg", "pos", "neg", "neutral", "neutral", "pos", "neg", "neutral", "neutral", "pos", "neg", "neg", "pos", "neutral", "neg", "neutral", "neutral", "neutral", "neutral", "neg", "pos", "neg", "neutral", "neutral", "neutral", "neutral", "neg", "pos", "neutral", "neg", "neutral", "neg", "neg", "neutral", "neutral", "neg", "neutral", "neutral", "neg", "pos", "neutral", "neutral", "neg", "neg", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neutral", "neg", "neutral", "neutral", "neutral", "neg", "neg", "neutral", "neutral", "neutral", "pos", "neutral", "pos", "neutral", "pos", "pos", "neutral", "neutral", "pos", "neutral", "pos", "neutral", "neutral", "neutral", "neg", "neutral", "pos", "neutral", "neutral", "neutral", "pos", "neutral", "neutral", "pos", "neutral", "pos", "neg", "neutral", "neg", "neutral", "neutral", "pos", "pos", "neutral", "neutral", "pos", "neg", "neutral", "neg", "neutral", "neutral", "neutral", "pos", "pos", "neutral", "neg", "pos", "pos", "neutral", "neutral", "neutral", "neg", "neutral", "pos", "pos", "neutral", "pos", "neutral", "pos", "pos", "neutral", "neutral", "neutral", "neutral", "neutral", "neutral", "pos", "neg", "pos", "pos", "pos", "pos", "neutral",  ...

# %% [markdown]
# ### Extracting topics

# %% [markdown]
# TOPICS Extraction
#
# I have shared a very basic tutorial on how to extract topics from text using non-negative matrix factorization;
# We don't have to implement an exact factorization, an approximation using gradient descent is more than enough.
#
# Check out this :3
# (https://yassine-mhedhbi.github.io/2020/02/28/nmf.html)

# %%
import logging 


logging.basicConfig(filename='logs/nmf.log', level=logging.DEBUG,
                    format='%(asctime)s:%(levelname)s:%(message)s')


def pen(A) : return (((A < 0) * A)**2).mean()
def loss(M): return (M - W@H).norm(2) + 1e6*pen(W) + 1e6*pen(H)

def NFM(M, d, a, epochs=1000):
    """M: initial matrix, d: intermediate shape i.e. (mxn)-> (mxd)(d,n), a: learning late alpha, epochs: number of epochs"""
    M = torch.Tensor(M).cuda()
    m, n = M.shape
    
    with torch.no_grad():
      W = torch.randn((m,d), requires_grad=True, dtype=torch.float, device='cuda:0').abs_()
      H = torch.randn((d,n), requires_grad=True, dtype=torch.float, device='cuda:0').abs_()
    losses = []
    i = 0
    opt = torch.optim.Adam([W,H], lr=5e-3, betas=(0.9,0.9))
    for i in range(epochs):
        opt.zero_grad()
        l = (M - W @ H).norm(2) + 1e6* (((W < 0) * W)**2).mean() + 1e6*(((H < 0) * H)**2).mean()
        losses.append(l)
        l.backward()
        #update our parameters.
        opt.step()
        i += 1
        if i % 50 == 0:
            a = a * 0.8
            logging.info(f'{i} loss: {(M - W @ H).norm(2).mean().item()}, min value in W: {W.min()}, min value in H: {H.min()}')
    
    return W, H, losses

# %%
vectorizer_tfidf = TfidfVectorizer(stop_words='english')
vectors = vectorizer_tfidf.fit_transform(clean_tweets[:20000]).todense() 
vectors.shape
# Out:
# (20000, 27746)

# %%
W, H , _ = NFM(vectors, 3, 0.01)
vocab = np.array(vectorizer_tfidf.get_feature_names())

# %%
def show_topics(H, num_top_words):
    top_words = lambda t: [vocab[i] for i in np.argsort(t)[:-num_top_words-1:-1]]
    topic_words = ([top_words(t) for t in H])
    return [', '.join(t) for t in topic_words]

Topics = show_topics(H.cpu().detach().numpy(), 6)

# %%
print('Extracting Topics:')
for i, topic in enumerate(Topics):
  print(f"{i}: {topic}")
# Out:
# Extracting Topics:
# 0: https, coronavirus, lockdown, people, trump, testing
# 1: deaths, italy, cases, number, total, new
# 2: china, sterilization, farmer, penalty, wetmarkets, dictatorship

# %%
sentiment
# Out:
# Empty DataFrame
# Columns: [tweet, Polarity, sentiment]
# Index: []
